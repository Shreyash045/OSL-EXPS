# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=sns.load_dataset("flights")
tips=sns.load_dataset("tips")
t=sns.load_dataset("titanic")
dia=sns.load_dataset("diamonds")
i=sns.load_dataset("iris")

# %%
#Visualizing statistical relationships:
#Replot

# %%
#Scatter plot

sns.relplot(x="passengers", y="month", data=a)

# %%
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time",data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day", col_wrap=2)

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", col="time",
    hue="time", size="size", style="sex",
    palette=["b", "r"], sizes=(10, 100)
)

# %%
#line plot

sns.relplot(x="total_bill", y="tip",kind="line", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="size",kind="line", data=tips)

# %%
flights_wide = sns.load_dataset("flights").pivot("year", "month", "passengers")
sns.relplot(data=flights_wide, kind="line")

# %%
#Bar plot

sns.catplot(y="total_bill",x="time",kind="bar", data=tips)

# %%
sns.catplot(y="total_bill",x="time",kind="bar", hue="smoker",palette="BuGn_r", data=tips)

# %%
#Count plot

sns.catplot( x="time", kind="count", palette="magma",data=tips)

# %%
sns.catplot( y="time",palette="Accent", kind="count", data=tips)

# %%
sns.catplot( y="time",palette="pastel",hue="smoker",edgecolor=".6", kind="count", data=tips)

# %%
sns.catplot(y="deck", hue="class", kind="count",
            palette="pastel", edgecolor=".6",
            data=t)

# %%
#Point plot

sns.catplot(x="day",y="total_bill",kind="point",data=tips)

# %%
sns.catplot(x="day",y="total_bill",hue="smoker",kind="point",palette="BrBG",data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            palette={"Yes": "g", "No": "m"},
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=tips)

# %%
sns.catplot(x="sex",y="survived",kind="point",data=t)

# %%
sns.catplot(x="class",y="survived",hue="sex",palette={"male":"g","female":"m"},markers=["^","o"],kind="point",data=t)

# %%
sns.catplot(x="class", y="survived", hue="sex",
            palette={"male":"g","female":"m"},
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=t)

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="point", data=t)

# %%
#Plotting Categorical Data

# %%
#Strip plot

sns.catplot(x="day", y="total_bill", data=tips)

# %%
 sns.catplot(x="day", y="total_bill", jitter=False, palette="Paired",data=tips)

# %%
sns.catplot(x="size", y="total_bill", data=tips)

# %%
sns.catplot(x="smoker", y="tip", order=["No", "Yes"], data=tips)

# %%
#Swarn plot

sns.catplot(x="day", y="total_bill", kind="swarm", data=tips)

# %%
 sns.catplot(x="total_bill", y="day", hue="time", kind="swarm",palette="Dark2", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm",data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="time", kind="swarm", data=tips)

# %%
#Box plot

sns.catplot(x="day", y="total_bill", kind="box", data=tips)

# %%
sns.catplot(x="day",y="total_bill",hue="smoker",kind="box",data=tips)

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.catplot(x="day", y="total_bill", hue="weekend",
            kind="box", dodge=False, data=tips)

# %%
sns.catplot(data=i, orient="h", kind="box")

# %%
sns.catplot(x="tip",y="total_bill",kind="boxen",data=tips.sort_values("tip"))

# %%
sns.boxenplot(x="time", y="tip", data=tips,

                   order=["Dinner", "Lunch"])
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
#Volini plot

sns.catplot(x="total_bill", y="day", hue="sex",palette="OrRd_r",kind="violin", data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="sex",kind="violin", bw=.10, cut=0.5,data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="violin", split=True, data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="violin", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex",kind="violin", inner="stick", split=True,palette="pastel", data=tips)

# %%
sns.violinplot(x=i.species, y=i.sepal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
#Multiple relationships with facets

g = sns.catplot(x="day", y="total_bill", kind="violin", inner=None, data=tips)
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips, ax=g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
g = sns.catplot(x="day", y="total_bill", kind="violin", inner=None, data=tips)
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips, ax=g.ax)
g.set(xscale="log");

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            col="time", aspect=.7,
            kind="swarm", data=tips)

# %%
g = sns.catplot(x="fare", y="survived", row="class",
                kind="box", orient="h", height=1.5, aspect=4,
                data=t.query("fare > 0"))
g.set(xscale="log")

# %%
#KDE plot

sns.kdeplot(data=tips, x="total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, y="total_bill")
# Out:
# <AxesSubplot:xlabel='Density', ylabel='total_bill'>

# %%
sns.kdeplot(data=i)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill", bw_adjust=.3)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
ax= sns.kdeplot(data=tips, x="total_bill", bw_adjust=5, cut=0)
sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True)

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="fill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="stack")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(
    data=tips, x="total_bill", hue="time",
    cumulative=True, common_norm=False, common_grid=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
tips_agg = (tips
    .groupby("size")
    .agg(total_bill=("total_bill", "mean"), n=("total_bill", "count"))
)
sns.kdeplot(data=tips_agg, x="total_bill", weights="n")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(
   data=tips, x="total_bill", hue="size",
   fill=True, common_norm=False, palette="Accent",
   alpha=.6, linewidth=0,
)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill",hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill",hue="sex",fill=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>
